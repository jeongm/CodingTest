# %% [markdown]
# https://www.acmicpc.net/problem/1010

# %%
T = int(input())
site = [list(map(int,input().split()))for i in range(T)]
# Out:
# 4
# 2 2
# 1 5
# 4 7
# 13 29

# %%
def case(n):
    if n == 0:
        return 0
    elif n == 1:
        return 1
    return n + case(n-1)

# %%
for si in site:
    site_num = 0
    for j in range(si[1]-si[0]):
        for i in range(1,si[0]+1):
            print(case(i))
            site_num += case(i)
    
    print("경우의 수",site_num)
# Out:
# 경우의 수 0
# 1
# 1
# 1
# 1
# 경우의 수 4
# 1
# 3
# 6
# 10
# 1
# 3
# 6
# 10
# 1
# 3
# 6
# 10
# 경우의 수 60
# 1
# 3
# 6
# 10
# 15
# 21
# 28
# 36
# 45
# 55
# 66
# 78
# 91
# 1
# 3
# 6
# 10
# 15
# 21
# 28
# 36
# 45
# 55
# 66
# 78
# 91
# 1
# 3
# 6
# 10
# 15
# 21
# 28
# 36
# 45
# 55
# 66
# 78
# 91
# 1
# 3
# 6
# 10
# 15
# 21
# 28
# 36
# 45
# 55
# 66
# 78
# 91
# 1
# 3
# 6
# 10
# 15
# 21
# 28
# 36
# 45
# 55
# 66
# 78
# 91
# 1
# 3
# 6
# 10
# 15
# 21
# 28
# 36
# 45
# 55
# 66
# 78
# 91
# 1
# 3
# 6
# 10
# 15
# 21
# 28
# 36
# 45
# 55
# 66
# 78
# 91
# 1
# 3
# 6
# 10
# 15
# 21
# 28
# 36
# 45
# 55
# 66
# 78
# 91
# 1
# 3
# 6
# 10
# 15
# 21
# 28
# 36
# 45
# 55
# 66
# 78
# 91
# 1
# 3
# 6
# 10
# 15
# 21
# 28
# 36
# 45
# 55
# 66
# 78
# 91
# 1
# 3
# 6
# 10
# 15
# 21
# 28
# 36
# 45
# 55
# 66
# 78
# 91
# 1
# 3
# 6
# 10
# 15
# 21
# 28
# 36
# 45
# 55
# 66
# 78
# 91
# 1
# 3
# 6
# 10
# 15
# 21
# 28
# 36
# 45
# 55
# 66
# 78
# 91
# 1
# 3
# 6
# 10
# 15
# 21
# 28
# 36
# 45
# 55
# 66
# 78
# 91
# 1
# 3
# 6
# 10
# 15
# 21
# 28
# ...

# %%
def case(n,m,site_case):
    site = m-n+1
    for i in range(m-n+1):
        for j in range(m-n+1):
            site += 1
        print(n,m,site_case)
            
    return site_case

# %%
case(1,4,0)
case(2,2,0)
case(4,7,0)
# Out:
# 1 4 4
# 1 4 7
# 1 4 9
# 1 4 10
# 2 2 1
# 1

# %%
sum = 0

for i in range(4):
    sum+= i

# %%
print(sum)
# Out:
# 6

# %%
def case(n,m,sc):
    if n == 0:
        return 0
    for i in range(m-n+1):# 시작과 끝을 정해볼까
        sc += 1
        case(n-1,m,sc)
        print(sc)

# %%
case(2,2,0)
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "C:\Users\jeong\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3437, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-67-8e83504e5969>", line 1, in <module>
#     case(2,2,0)
#   File "<ipython-input-66-b2bf52b8bbab>", line 4, in case
#     case(n-1,m,sc)
#   File "<ipython-input-66-b2bf52b8bbab>", line 4, in case
#     case(n-1,m,sc)
#   File "<ipython-input-66-b2bf52b8bbab>", line 4, in case
#     case(n-1,m,sc)
#   [Previous line repeated 2954 more times]
#   File "<ipython-input-66-b2bf52b8bbab>", line 2, in case
#     for i in range(m-n+1):# 시작과 끝을 정해볼까
# RecursionError: maximum recursion depth exceeded in comparison
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
# ...

# %%
case(1,4,0)
